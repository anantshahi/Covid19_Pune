# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Dataset/pmc.csv')

# %%
df
# Out:
#      Unnamed: 0  dailysamples  dailyconfirmed  dailyrecovered  dailydeceased  \
# 0             1           153              15             0.0              2
# 1             2           115              33             1.0              2
# 2             3           157              44             1.0              4
# 3             4           220              55             1.0              4
# 4             5           265              65             0.0              5
# ..          ...           ...             ...             ...            ...
# 109         110          5863            1506          1791.0             23
# 110         111          3620            1271          1203.0             31
# 111         112          4604            1270          1822.0             18
# 112         113          5595            1192          1312.0             28
# 113         114          5698            1101          1159.0             17
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'dailysamples', 'dailyconfirmed', 'dailyrecovered',
#        'dailydeceased', 'totalcritical', 'ventilatorpatients', 'totalsamples',
#        'totalconfirmed', 'totalhospital', 'totalrecovered', 'totaldeceased',
#        'totalhousesurvey', 'populationcovered', 'housescovered', 'flu',
#        'Date'],
#       dtype='object')

# %%
df.drop(columns='Unnamed: 0',inplace = True)

# %%
df
# Out:
#      dailysamples  dailyconfirmed  dailyrecovered  dailydeceased  \
# 0             153              15             0.0              2
# 1             115              33             1.0              2
# 2             157              44             1.0              4
# 3             220              55             1.0              4
# 4             265              65             0.0              5
# ..            ...             ...             ...            ...
# 109          5863            1506          1791.0             23
# 110          3620            1271          1203.0             31
# 111          4604            1270          1822.0             18
# 112          5595            1192          1312.0             28
# 113          5698            1101          1159.0             17
#
#      totalcritical  ventilatorpatients  totalsamples  totalconfirmed  \
# 0              NaN                 NaN          2231             255
# ...

# %%
corr = df.corr()

# %%
plt.figure(figsize=(30,30))

sns.heatmap(corr,annot= True)

# %%
df1 = df[['dailysamples','dailyconfirmed','Date']]

# %%
df1
# Out:
#      dailysamples  dailyconfirmed        Date
# 0             153              15  12.04.2020
# 1             115              33  13.04.2020
# 2             157              44  14.04.2020
# 3             220              55  15.04.2020
# 4             265              65  16.04.2020
# ..            ...             ...         ...
# 109          5863            1506   1.08.2020
# 110          3620            1271   2.08.2020
# 111          4604            1270   3.08.2020
# 112          5595            1192   4.08.2020
# 113          5698            1101   5.08.2020
#
# [114 rows x 3 columns]

# %%
plt.figure(figsize=(30,30))
x = df1['dailyconfirmed']
y = df1['dailyconfirmed']

sns.lineplot('dailyconfirmed','dailysamples',data = df1)

# %%
plt.figure(figsize=(10,10))
x = df1['dailyconfirmed']
y = df1['dailyconfirmed']

sns.scatterplot('dailyconfirmed','dailysamples',data = df1)
plt.tight_layout()

# %%
from sklearn import preprocessing, svm 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 


X = np.array(df1['dailysamples']).reshape(-1, 1) 
y = np.array(df1['dailyconfirmed']).reshape(-1, 1) 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25) 
  
# Splitting the data into training and testing data 
regr = LinearRegression() 
  
regr.fit(X_train, y_train) 
#print(regr.score(X_test, y_test)) 
predictions=regr.predict(8950)
print(predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-1bdd1a5e933a> in <module>
#      14 regr.fit(X_train, y_train)
#      15 #print(regr.score(X_test, y_test))
# ---> 16 predictions=regr.predict(8950)
#      17 print(predictions)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     205         check_is_fitted(self)
#     206
# --> 207         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     208         return safe_sparse_dot(X, self.coef_.T,
#     209                                dense_output=True) + self.intercept_
#
# ...
